# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
temp_mag = np.genfromtxt("scratch/temp_mag.txt")

# %%
plt.scatter(temp_mag[:,0], temp_mag[:,1])

# %%
expdir = "/home/jpriessnitz/domainwall/scratch/bulkCo_Tc/no1/"
Ts = np.arange(0, 1501, 10)
mags = []
for T in Ts:
    averages = np.genfromtxt(os.path.join(expdir, "run_{}".format(T), "averages.EXP_NAME.out"))
    mags.append(averages[-1,4])

# %%
plt.scatter(Ts, mags)

plt.scatter(temp_mag[:,0]*2, temp_mag[:,1])

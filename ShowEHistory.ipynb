# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML
# plt.rcParams['figure.figsize'] = [8, 6]
# plt.rcParams['figure.dpi'] = 200

# %%
Ehistory = np.genfromtxt("build/magsim/Ehistory.out")
xs = np.arange(len(Ehistory))
Ts = Ehistory[:,0]
Ts /= np.max(Ts)
Es = Ehistory[:,1]
Es /= np.min(Es)
Es = 1 - Es

# %%
# %matplotlib notebook
plt.plot(Ts)
plt.plot(Es)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
